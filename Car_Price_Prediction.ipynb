# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df=pd.read_csv('car_price_prediction.csv')

# %%
df1=int(df['Mileage'][0].strip(' km'))

# %%
df1
# Out:
# 186005

# %%
a=0
for i in df['Mileage']:
    df['Mileage'][a]=int(i.strip(' km'))
    a=a+1

# %%
df['Mileage']
# Out:
# 0        186005
# 1        192000
# 2        200000
# 3        168966
# 4         91901
#           ...
# 19232    300000
# 19233    161600
# 19234    116365
# 19235     51258
# 19236    186923
# Name: Mileage, Length: 19237, dtype: object

# %%
type(df['Mileage'][0])
# Out:
# int

# %%
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
a=0
b=0
for i in df['Levy']:
    if i == '-':
        df['Levy'][a]=0
    else:
        df['Levy'][a]=int(i)
    a=a+1

# %%
mean = df['Levy'].mean()
for i in df['Levy']:
    if i == 0:
        df['Levy'][b]=mean
    b=b+1

# %%
df
# Out:
#              ID  Price        Levy   Manufacturer    Model  Prod. year  \
# 0      45654403  13328        1399          LEXUS   RX 450        2010
# 1      44731507  16621        1018      CHEVROLET  Equinox        2011
# 2      45774419   8467  632.528669          HONDA      FIT        2006
# 3      45769185   3607         862           FORD   Escape        2011
# 4      45809263  11726         446          HONDA      FIT        2014
# ...         ...    ...         ...            ...      ...         ...
# 19232  45798355   8467  632.528669  MERCEDES-BENZ  CLK 200        1999
# 19233  45778856  15681         831        HYUNDAI   Sonata        2011
# 19234  45804997  26108         836        HYUNDAI   Tucson        2010
# 19235  45793526   5331        1288      CHEVROLET  Captiva        2007
# 19236  45813273    470         753        HYUNDAI   Sonata        2012
#
#         Category Leather interior Fuel type Engine volume Mileage  Cylinders  \
# ...

# %%
for index,item in enumerate(df.Manufacturer.unique()):
    for index2,i in enumerate(df['Manufacturer']):
        if i == item:
            df['Manufacturer'][index2]=index

# %%
for index,item in enumerate(df.Model.unique()):
    for index2,i in enumerate(df['Model']):
        if i == item:
            df['Model'][index2]=index

# %%
for index,item in enumerate(df.Category.unique()):
    for index2,i in enumerate(df['Category']):
        if i == item:
            df['Category'][index2]=index

# %%
for index,i in enumerate(df['Leather interior']):
    if i == 'Yes':
        df['Leather interior'][index] = 1
    elif i == 'No':
        df['Leather interior'][index] = 0

# %%
df['Leather interior'][0]
# Out:
# 1

# %%
for index,item in enumerate(df['Fuel type'].unique()):
    for index2,i in enumerate(df['Fuel type']):
        if i == item:
            df['Fuel type'][index2]=index

# %%
df['Fuel type']
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 19232    3
# 19233    1
# 19234    2
# 19235    2
# 19236    0
# Name: Fuel type, Length: 19237, dtype: object

# %%
for index,i in enumerate(df['Fuel type'].unique()):
    for index2,i in enumerate(df['Fuel type']):
        if i == item:
            df['Fuel type'][index2]=index

# %%
def my_func(name):
    for index,item in enumerate(df[name].unique()):
        for index2,i in enumerate(df[name]):
            if i == item:
                df[name][index2]=index

# %%
my_func('Engine volume')

# %%
df['Engine volume']
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         2
#          ..
# 19232    10
# 19233     6
# 19234     4
# 19235     4
# 19236     6
# Name: Engine volume, Length: 19237, dtype: object

# %%
my_func('Gear box type')

# %%
my_func('Drive wheels')

# %%
my_func('Doors')

# %%
my_func('Wheel')

# %%
my_func('Color')

# %%
df
# Out:
#              ID  Price        Levy Manufacturer Model  Prod. year Category  \
# 0      45654403  13328        1399            0     0        2010        0
# 1      44731507  16621        1018            1     1        2011        0
# 2      45774419   8467  632.528669            2     2        2006        1
# 3      45769185   3607         862            3     3        2011        0
# 4      45809263  11726         446            2     2        2014        1
# ...         ...    ...         ...          ...   ...         ...      ...
# 19232  45798355   8467  632.528669            6   383        1999        6
# 19233  45778856  15681         831            4     6        2011        2
# 19234  45804997  26108         836            4    42        2010        0
# 19235  45793526   5331        1288            1    44        2007        0
# 19236  45813273    470         753            4     6        2012        2
#
#       Leather interior Fuel type Engine volume Mileage  Cylinders  \
# ...

# %%
features =['Levy','Manufacturer','Model','Prod. year','Category','Leather interior','Fuel type','Engine volume','Mileage','Cylinders','Gear box type','Drive wheels','Doors','Wheel','Color','Airbags']
label=['Price']
X = df[features].values
y= df[label].values

# %%
X
# Out:
# array([[1399, 0, 0, ..., 0, 0, 12],
#        [1018, 1, 1, ..., 0, 1, 8],
#        [632.5286687113376, 2, 2, ..., 1, 1, 2],
#        ...,
#        [836, 4, 42, ..., 0, 3, 4],
#        [1288, 1, 44, ..., 0, 1, 4],
#        [753, 4, 6, ..., 0, 2, 12]], dtype=object)

# %%
y
# Out:
# array([[13328],
#        [16621],
#        [ 8467],
#        ...,
#        [26108],
#        [ 5331],
#        [  470]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split



# 60% Train, 20% Validation, %20 Test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42) 

X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)



print(f'Total # of sample in whole dataset: {len(X)}')

print(f'Total # of sample in train dataset: {len(X_train)}')

print(f'Total # of sample in validation dataset: {len(X_valid)}')

print(f'Total # of sample in test dataset: {len(X_test)}')
# Out:
# Total # of sample in whole dataset: 19237
# Total # of sample in train dataset: 11542
# Total # of sample in validation dataset: 3847
# Total # of sample in test dataset: 3848

# %%
from sklearn.linear_model import LinearRegression



# Create linear regression object

reg = LinearRegression()



# Train the model using the training sets

reg.fit(X_train, y_train)

from sklearn.metrics import mean_absolute_error



predictions = reg.predict(X_valid)

print(f'MAE Score: {mean_absolute_error(predictions, y_valid)}')
# Out:
# MAE Score: 13486.167348991165

# %%
reg = LinearRegression(normalize=True)

reg.fit(X_train, y_train)



predictions = reg.predict(X_valid)

print(f'MAE Score: {mean_absolute_error(predictions, y_valid)}')
# Out:
# MAE Score: 13486.167349003368
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
from sklearn.linear_model import PoissonRegressor 
poi_reg = PoissonRegressor(max_iter=3847)

poi_reg.fit(X_train, y_train.ravel())



predictions = poi_reg.predict(X_valid)

print(f'MAE Score: {mean_absolute_error(predictions, y_valid)}')
# Out:
# MAE Score: 12772.152630347853
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)

# %%
poi_reg = PoissonRegressor(max_iter=10000)

poi_reg.fit(X_train, y_train.ravel())



predictions = poi_reg.predict(X_valid)

print(f'MAE Score: {mean_absolute_error(predictions, y_valid)}')
# Out:
# MAE Score: 12772.152630347853
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)

# %%
poi_reg = PoissonRegressor(tol=1e-2, max_iter=10000)

poi_reg.fit(X_train, y_train.ravel())



predictions = poi_reg.predict(X_valid)

print(f'MAE Score: {mean_absolute_error(predictions, y_valid)}')
# Out:
# MAE Score: 12772.152630347853
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)

# %%
#Trying cross validation



from sklearn.model_selection import cross_validate

from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error



scoring = {'mae': make_scorer(mean_absolute_error)}



model = LinearRegression()

scores = cross_validate(model, X_train, y_train, cv=10, scoring=scoring)



print(f"Average cross validation MAE score: {scores['test_mae'].mean()}")
# Out:
# Average cross validation MAE score: 16087.444258510903

# %%
model = LinearRegression(normalize=True)

scores = cross_validate(model, X_train, y_train, cv=10, scoring=scoring)



print(f"Average cross validation MAE score: {scores['test_mae'].mean()}")
# Out:
# Average cross validation MAE score: 16087.444258521946
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
model = PoissonRegressor(max_iter=1000)

scores = cross_validate(model, X_train, y_train.ravel(), cv=10, scoring=scoring)



print(f"Average cross validation MAE score: {scores['test_mae'].mean()}")
# Out:
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
# ...

# %%
#Now with the model we get the least mae we use that model to apply predictions on our test set

from sklearn.metrics import mean_absolute_error



model = PoissonRegressor(max_iter=3847)

model.fit(X_train, y_train)



predictions = model.predict(X_test)

print(f'Test (Final) MAE Score: {mean_absolute_error(predictions, y_test)}')
# Out:
# Test (Final) MAE Score: 12958.609048630493
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\alphant.INGAGE\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)

# %%
predictions
# Out:
# array([19370.42384335, 19370.42384335, 19370.42384335, ...,
#        19370.42384335, 19370.42384335, 19370.42384335])
